# %% [markdown]
# # Notebook to get you started

# %%
import numpy as np
import pandas as pd

# %%
df08 = pd.read_csv("/Users/vedikabaradwaj/pdi_pensions/pdi_pensions/data/csv/morg08.csv")
df09 = pd.read_csv("data/csv/morg09.csv")
df10 = pd.read_csv("data/csv/morg10.csv")
df11 = pd.read_csv("data/csv/morg11.csv")
df12 = pd.read_csv("data/csv/morg12.csv")
df13 = pd.read_csv("data/csv/morg13.csv")
df14 = pd.read_csv("data/csv/morg14.csv")
df15 = pd.read_csv("data/csv/morg15.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 df08 = pd.read_csv("/Users/vedikabaradwaj/pdi_pensions/pdi_pensions/data/csv/morg08.csv")
# ----> 2 df09 = pd.read_csv("data/csv/morg09.csv")
#       3 df10 = pd.read_csv("data/csv/morg10.csv")
#       4 df11 = pd.read_csv("data/csv/morg11.csv")
#
# ...

# %%
df14=pd.read_csv("/Users/vedikabaradwaj/pdi_pensions/pdi_pensions/data/csv/morg14.csv")

# %%
#SETTING UP WEIGHT COLUMNS
month_col = "intmonth"
wcol = "weight"

# %%
df14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317056 entries, 0 to 317055
# Data columns (total 99 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   hhid       317056 non-null  int64
#  1   intmonth   317056 non-null  int64
#  2   hurespli   317024 non-null  float64
#  3   hrhtype    317056 non-null  int64
#  4   minsamp    317056 non-null  int64
#  5   hrlonglk   317056 non-null  int64
#  6   hrsample   317056 non-null  int64
#  7   hrhhid2    317056 non-null  int64
#  8   serial     317056 non-null  int64
#  9   hhnum      317056 non-null  int64
#  10  state      78801 non-null   float64
#  11  stfips     317056 non-null  int64
#  12  cbsafips   317056 non-null  int64
#  13  county     317056 non-null  int64
#  14  centcity   258803 non-null  float64
#  15  smsastat   314133 non-null  float64
#  16  icntcity   29414 non-null   float64
#  17  smsa04     317056 non-null  int64
#  18  relref95   317056 non-null  int64
# ...

# %%
#FILTERING FOR PUBLIC WORKERS ONLY
df08_public = df08[df08["class94"].isin([1, 2, 3])].copy()
print("Public workers (unweighted N):", df08_public.shape[0])
# Out:
# Public workers (unweighted N): 32403

# %%
#WITH WEIGHTS
monthly_public = (
    df08_public
        .groupby(month_col)[wcol]
        .sum())

annual_public = monthly_public.mean()

print("Public workers (annual average, weighted):", annual_public)
# Out:
# Public workers (annual average, weighted): 5672116.830499999
